# %%
import server
from qiskit import QuantumCircuit
import matplotlib.pyplot as plt
sv = server.Server()

# %%
qc = QuantumCircuit(2)
qc.rx(-2.11, 1)
qc.draw()

# %%
sv.probe(vault_index=9, circuit=qc.qasm())
# Out:
# {'0': 0.885, '1': 0.025, '2': 0.05, '3': 0.04}

# %%
sv.state()
# Out:
# {'team': 'Qnonymous',
#  'totalAvgScore': 0.2176730769230769,
#  'topVaultScores': [0.8,
#   0,
#   0,
#   0,
#   0,
#   0.9230769230769231,
#   0,
#   0.002,
#   0,
#   0.746,
#   0.941,
#   0,
#   0],
#  'probesRemaining': [34, 19, 20, 20, 20, 5, 20, 16, 20, 12, 10, 20, 15],
#  'attacksRemaining': [36, 20, 20, 20, 20, 16, 20, 19, 20, 19, 17, 20, 20],
#  'reminder': 'Vault index 0 is a test vault, and does not count towards your final score.'}

# %%
sv.attack(vault_index=9, circuit=qc.qasm())
# Out:
# {'costFactor': 1, 'rawScore': 0.8555, 'score': 0.8555}

# %%
z_meas = {'0': 0.005,
 '2': 0.005,
 '4': 0.015,
 '5': 0.01,
 '8': 0.025,
 '10': 0.015,
 '16': 0.03,
 '18': 0.08,
 '20': 0.01,
 '24': 0.595,
 '25': 0.015,
 '26': 0.175,
 '27': 0.01,
 '28': 0.005,
 '30': 0.005}

y_meas = {'0': 0.045,
 '1': 0.06,
 '2': 0.005,
 '3': 0.04,
 '4': 0.015,
 '5': 0.03,
 '6': 0.01,
 '7': 0.015,
 '9': 0.015,
 '10': 0.015,
 '11': 0.025,
 '12': 0.015,
 '13': 0.02,
 '14': 0.02,
 '15': 0.02,
 '16': 0.03,
 '17': 0.085,
 '18': 0.005,
 '19': 0.005,
 '20': 0.025,
 '21': 0.04,
 '22': 0.045,
 '23': 0.055,
 '24': 0.03,
 '25': 0.08,
 '26': 0.04,
 '27': 0.045,
 '28': 0.035,
 '29': 0.04,
 '30': 0.025,
 '31': 0.065}

x_meas = {'0': 0.035,
 '1': 0.005,
 '2': 0.035,
 '3': 0.035,
 '4': 0.045,
 '5': 0.03,
 '6': 0.055,
 '7': 0.035,
 '10': 0.085,
 '11': 0.03,
 '12': 0.015,
 '13': 0.02,
 '14': 0.085,
 '15': 0.13,
 '16': 0.035,
 '17': 0.02,
 '18': 0.06,
 '19': 0.035,
 '22': 0.045,
 '23': 0.03,
 '24': 0.005,
 '26': 0.025,
 '27': 0.01,
 '28': 0.005,
 '30': 0.05,
 '31': 0.04}

# %%
sv.state()
# Out:
# {'team': 'Qnonymous',
#  'totalAvgScore': 0.038384615384615385,
#  'topVaultScores': [0.8, 0, 0, 0, 0, 0.46061538461538465, 0, 0, 0, 0, 0, 0, 0],
#  'probesRemaining': [34, 19, 20, 20, 20, 6, 20, 20, 20, 16, 20, 20, 20],
#  'attacksRemaining': [37, 20, 20, 20, 20, 17, 20, 20, 20, 20, 20, 20, 20],
#  'reminder': 'Vault index 0 is a test vault, and does not count towards your final score.'}

# %%
def plot(res):
    # Convert keys to integers and sort them
    keys_as_int = sorted(map(int, res.keys()))

    # Convert integers to binary representation in big endian
    binary_labels = [format(key, '05b') for key in keys_as_int]
    print(binary_labels)

    # Extract corresponding values
    values = [res[str(key)] for key in keys_as_int]

    # Plotting
    plt.bar(binary_labels, values)
    plt.xlabel('Binary Number (Big Endian)')
    plt.ylabel('Value')
    plt.title('Histogram of Result Object')
    plt.show()

# %%
plot({'0': 0.005,
 '2': 0.005,
 '4': 0.015,
 '6': 0.005,
 '7': 0.005,
 '8': 0.025,
 '10': 0.01,
 '11': 0.005,
 '16': 0.03,
 '18': 0.08,
 '20': 0.01,
 '24': 0.595,
 '26': 0.18,
 '27': 0.02,
 '28': 0.005,
 '31': 0.005})
# Out:
# ['00000', '00010', '00100', '00110', '00111', '01000', '01010', '01011', '10000', '10010', '10100', '11000', '11010', '11011', '11100', '11111']

# %%
plot(z_meas)
# Out:
# ['00000', '00010', '00100', '00101', '01000', '01010', '10000', '10010', '10100', '11000', '11001', '11010', '11011', '11100', '11110']

# %%
plot({'1': 0.005,
 '3': 0.005,
 '5': 0.025,
 '9': 0.025,
 '11': 0.015,
 '17': 0.03,
 '19': 0.08,
 '20': 0.005,
 '21': 0.005,
 '24': 0.01,
 '25': 0.6,
 '27': 0.185,
 '29': 0.005,
 '31': 0.005})
# Out:
# ['00001', '00011', '00101', '01001', '01011', '10001', '10011', '10100', '10101', '11000', '11001', '11011', '11101', '11111']

# %%
plot(x_meas)
# Out:
# ['00000', '00001', '00010', '00011', '00100', '00101', '00110', '00111', '01010', '01011', '01100', '01101', '01110', '01111', '10000', '10001', '10010', '10011', '10110', '10111', '11000', '11010', '11011', '11100', '11110', '11111']

# %%
plot(y_meas)
# Out:
# ['00000', '00001', '00010', '00011', '00100', '00101', '00110', '00111', '01001', '01010', '01011', '01100', '01101', '01110', '01111', '10000', '10001', '10010', '10011', '10100', '10101', '10110', '10111', '11000', '11001', '11010', '11011', '11100', '11101', '11110', '11111']

# %%
a={'0': 0.155, '1': 0.76, '2': 0.015, '3': 0.07} #(ry on 0)
b={'0': 0.17, '1': 0.74, '3': 0.09} #(ry on 1)
